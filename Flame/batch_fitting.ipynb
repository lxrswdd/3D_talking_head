# %%
import os, sys
import cv2
import torch
import torchvision
import torch.nn.functional as F
import torch.nn as nn
import numpy as np
from glob import glob
import time
import datetime
import imageio

torch.backends.cudnn.benchmark = True

# %% [markdown]
# ### At this stage, use the smart_class environment

# %%
import Gen_Landmark

img_folder_dir = "/data/share/FLAME/facescape_fit/images"
out_dir = '/data/share/FLAME/facescape_fit/landmarks'

tt = Gen_Landmark.Gen2DLandmarks()
tt.main_process(img_dir = img_folder_dir,out_dir = out_dir)
# Out:
# Generate facial landmarks:  78%|███████▊  | 82/105 [00:17<00:01, 21.21it/s]/home/guest/anaconda3/envs/smart_class/lib/python3.10/site-packages/face_alignment/api.py:144: UserWarning: No faces were detected.
#   warnings.warn("No faces were detected.")
# Generate facial landmarks:  84%|████████▍ | 88/105 [00:17<00:00, 21.26it/s]
# Warning: can't predict the landmark info of /data/share/FLAME/facescape_fit/images/344_11_chin_raiser_14_roll_(-35,-10).jpg
# Warning: can't predict the landmark info of /data/share/FLAME/facescape_fit/images/344_11_chin_raiser_14_roll_(-35,-10).jpg
# Generate facial landmarks: 100%|██████████| 105/105 [00:18<00:00,  5.71it/s]

# %%
from Gen_facial_mask import *

img_folder_dir = "/data/share/FLAME/facescape_fit/images"
mask_out_dir = "/data/share/FLAME/facescape_fit/masks"

gen_face_mask(img_folder_dir=img_folder_dir,out_dir=mask_out_dir)
# Out:
# CUDA is available. Device:  NVIDIA RTX A6000
# 100%|██████████| 105/105 [00:14<00:00,  7.26it/s]

# %% [markdown]
# ### Starting this line below, run the flame environment

# %%
import sys
sys.path.append('/data/share/FLAME/Photometric_fitting/photometric_optimization')
import cv2
import os
import torch
import torchvision
import torch.nn.functional as F
import torch.nn as nn
import numpy as np
from glob import glob
from tqdm import tqdm
import datetime
import imageio
os.chdir("/data/share/FLAME/Photometric_fitting/photometric_optimization")
sys.path.append('/data/share/FLAME/Photometric_fitting/photometric_optimization/models')
from FLAME import FLAME, FLAMETex
from renderer import Renderer
import util
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ### Remember to change the directories in the following class if there is a change.

# %%
class PhotometricFitting(object):
    def __init__(self, config, device='cuda'):
        self.batch_size = config.batch_size
        self.image_size = config.image_size
        self.config = config
        self.device = device
        #
        self.flame = FLAME(self.config).to(self.device)
        self.flametex = FLAMETex(self.config).to(self.device)

        self._setup_renderer()

    def _setup_renderer(self):
        mesh_file = '/data/share/FLAME/Photometric_fitting/photometric_optimization/data/head_template_mesh.obj'
        self.render = Renderer(self.image_size, obj_filename=mesh_file).to(self.device)

    def optimize(self, images, landmarks, image_masks, savefolder=None):
        bz = images.shape[0]
        shape = nn.Parameter(torch.zeros(bz, self.config.shape_params).float().to(self.device))
        tex = nn.Parameter(torch.zeros(bz, self.config.tex_params).float().to(self.device))
        exp = nn.Parameter(torch.zeros(bz, self.config.expression_params).float().to(self.device))
        pose = nn.Parameter(torch.zeros(bz, self.config.pose_params).float().to(self.device))
        cam = torch.zeros(bz, self.config.camera_params); cam[:, 0] = 5.
        cam = nn.Parameter(cam.float().to(self.device))
        lights = nn.Parameter(torch.zeros(bz, 9, 3).float().to(self.device))
        e_opt = torch.optim.Adam(
            [shape, exp, pose, cam, tex, lights],
            lr=self.config.e_lr,
            weight_decay=self.config.e_wd
        )
        e_opt_rigid = torch.optim.Adam(
            [pose, cam],
            lr=self.config.e_lr,
            weight_decay=self.config.e_wd
        )

        gt_landmark = landmarks

        # rigid fitting of pose and camera with 51 static face landmarks,
        # this is due to the non-differentiable attribute of contour landmarks trajectory
        for k in range(200):
            losses = {}
            vertices, landmarks2d, landmarks3d = self.flame(shape_params=shape, expression_params=exp, pose_params=pose)
            trans_vertices = util.batch_orth_proj(vertices, cam);
            trans_vertices[..., 1:] = - trans_vertices[..., 1:]
            landmarks2d = util.batch_orth_proj(landmarks2d, cam);
            landmarks2d[..., 1:] = - landmarks2d[..., 1:]
            landmarks3d = util.batch_orth_proj(landmarks3d, cam);
            landmarks3d[..., 1:] = - landmarks3d[..., 1:]

            losses['landmark'] = util.l2_distance(landmarks2d[:, 17:, :2], gt_landmark[:, 17:, :2]) * config.w_lmks

            all_loss = 0.
            for key in losses.keys():
                all_loss = all_loss + losses[key]
            losses['all_loss'] = all_loss
            e_opt_rigid.zero_grad()
            all_loss.backward()
            e_opt_rigid.step()

            loss_info = '----iter: {}, time: {}\n'.format(k, datetime.datetime.now().strftime('%Y-%m-%d-%H:%M:%S'))
            for key in losses.keys():
                loss_info = loss_info + '{}: {}, '.format(key, float(losses[key]))
            if k % 10 == 0:
                print(loss_info)

            if k % 10 == 0:
                grids = {}
                visind = range(bz)  # [0]
                grids['images'] = torchvision.utils.make_grid(images[visind]).detach().cpu()
                grids['landmarks_gt'] = torchvision.utils.make_grid(
                    util.tensor_vis_landmarks(images[visind], landmarks[visind]))
                grids['landmarks2d'] = torchvision.utils.make_grid(
                    util.tensor_vis_landmarks(images[visind], landmarks2d[visind]))
                grids['landmarks3d'] = torchvision.utils.make_grid(
                    util.tensor_vis_landmarks(images[visind], landmarks3d[visind]))

                grid = torch.cat(list(grids.values()), 1)
                grid_image = (grid.numpy().transpose(1, 2, 0).copy() * 255)[:, :, [2, 1, 0]]
                grid_image = np.minimum(np.maximum(grid_image, 0), 255).astype(np.uint8)
                cv2.imwrite('{}/{}.jpg'.format(savefolder, k), grid_image)

        # non-rigid fitting of all the parameters with 68 face landmarks, photometric loss and regularization terms.
        for k in range(200, 1000):
            losses = {}
            vertices, landmarks2d, landmarks3d = self.flame(shape_params=shape, expression_params=exp, pose_params=pose)
            trans_vertices = util.batch_orth_proj(vertices, cam);
            trans_vertices[..., 1:] = - trans_vertices[..., 1:]
            landmarks2d = util.batch_orth_proj(landmarks2d, cam);
            landmarks2d[..., 1:] = - landmarks2d[..., 1:]
            landmarks3d = util.batch_orth_proj(landmarks3d, cam);
            landmarks3d[..., 1:] = - landmarks3d[..., 1:]

            losses['landmark'] = util.l2_distance(landmarks2d[:, :, :2], gt_landmark[:, :, :2]) * config.w_lmks
            losses['shape_reg'] = (torch.sum(shape ** 2) / 2) * config.w_shape_reg  # *1e-4
            losses['expression_reg'] = (torch.sum(exp ** 2) / 2) * config.w_expr_reg  # *1e-4
            losses['pose_reg'] = (torch.sum(pose ** 2) / 2) * config.w_pose_reg

            ## render
            albedos = self.flametex(tex) / 255.
            ops = self.render(vertices, trans_vertices, albedos, lights)
            predicted_images = ops['images']
            losses['photometric_texture'] = (image_masks * (ops['images'] - images).abs()).mean() * config.w_pho

            all_loss = 0.
            for key in losses.keys():
                all_loss = all_loss + losses[key]
            losses['all_loss'] = all_loss
            e_opt.zero_grad()
            all_loss.backward()
            e_opt.step()

            loss_info = '----iter: {}, time: {}\n'.format(k, datetime.datetime.now().strftime('%Y-%m-%d-%H:%M:%S'))
            for key in losses.keys():
                loss_info = loss_info + '{}: {}, '.format(key, float(losses[key]))

            if k % 10 == 0:
                print(loss_info)

            # visualize
            if k % 10 == 0:
                grids = {}
                visind = range(bz)  # [0]
                grids['images'] = torchvision.utils.make_grid(images[visind]).detach().cpu()
                grids['landmarks_gt'] = torchvision.utils.make_grid(
                    util.tensor_vis_landmarks(images[visind], landmarks[visind]))
                grids['landmarks2d'] = torchvision.utils.make_grid(
                    util.tensor_vis_landmarks(images[visind], landmarks2d[visind]))
                grids['landmarks3d'] = torchvision.utils.make_grid(
                    util.tensor_vis_landmarks(images[visind], landmarks3d[visind]))
                grids['albedoimage'] = torchvision.utils.make_grid(
                    (ops['albedo_images'])[visind].detach().cpu())
                grids['render'] = torchvision.utils.make_grid(predicted_images[visind].detach().float().cpu())
                shape_images = self.render.render_shape(vertices, trans_vertices, images)
                grids['shape'] = torchvision.utils.make_grid(
                    F.interpolate(shape_images[visind], [224, 224])).detach().float().cpu()


                # grids['tex'] = torchvision.utils.make_grid(F.interpolate(albedos[visind], [224, 224])).detach().cpu()
                grid = torch.cat(list(grids.values()), 1)
                grid_image = (grid.numpy().transpose(1, 2, 0).copy() * 255)[:, :, [2, 1, 0]]
                grid_image = np.minimum(np.maximum(grid_image, 0), 255).astype(np.uint8)

                cv2.imwrite('{}/{}.jpg'.format(savefolder, k), grid_image)

        single_params = {
            'shape': shape.detach().cpu().numpy(),
            'exp': exp.detach().cpu().numpy(),
            'pose': pose.detach().cpu().numpy(),
            'cam': cam.detach().cpu().numpy(),
            'verts': trans_vertices.detach().cpu().numpy(),
            'albedos':albedos.detach().cpu().numpy(),
            'tex': tex.detach().cpu().numpy(),
            'lit': lights.detach().cpu().numpy()
        }
        return single_params

    def run(self, imagepath, landmarkpath,image_mask_folder):
        # The implementation is potentially able to optimize with images(batch_size>1),
        # here we show the example with a single image fitting
        images = []
        landmarks = []
        image_masks = []

        image_name = os.path.basename(imagepath)[:-4]
        savefile = os.path.sep.join([self.config.savefolder,image_name ,image_name + '.npy'])

        # photometric optimization is sensitive to the hair or glass occlusions,
        # therefore we use a face segmentation network to mask the skin region out.
        # image_mask_folder = './FFHQ_seg/'
        image_mask_path = os.path.sep.join([image_mask_folder, image_name + '.npy'])

        image = cv2.resize(cv2.imread(imagepath), (config.cropped_size, config.cropped_size)).astype(np.float32) / 255.
        image = image[:, :, [2, 1, 0]].transpose(2, 0, 1)
        images.append(torch.from_numpy(image[None, :, :, :]).to(self.device))

        image_mask = np.load(image_mask_path, allow_pickle=True)
        image_mask = image_mask[..., None].astype('float32')
        image_mask = image_mask.transpose(2, 0, 1)
        image_mask_bn = np.zeros_like(image_mask)
        image_mask_bn[np.where(image_mask != 0)] = 1.
        image_masks.append(torch.from_numpy(image_mask_bn[None, :, :, :]).to(self.device))

        landmark = np.load(landmarkpath).astype(np.float32)
        landmark[:, 0] = landmark[:, 0] / float(image.shape[2]) * 2 - 1
        landmark[:, 1] = landmark[:, 1] / float(image.shape[1]) * 2 - 1
        landmarks.append(torch.from_numpy(landmark)[None, :, :].float().to(self.device))

        images = torch.cat(images, dim=0)
        images = F.interpolate(images, [self.image_size, self.image_size])
        image_masks = torch.cat(image_masks, dim=0)
        image_masks = F.interpolate(image_masks, [self.image_size, self.image_size])

        landmarks = torch.cat(landmarks, dim=0)
        savefolder = os.path.sep.join([self.config.savefolder, image_name])

        util.check_mkdir(savefolder)
        # optimize
        single_params = self.optimize(images, landmarks, image_masks, savefolder)
        self.render.save_obj(filename=savefile[:-4]+'.obj',
                             vertices=torch.from_numpy(single_params['verts'][0]).to(self.device),
                             textures=torch.from_numpy(single_params['albedos'][0]).to(self.device)
                             )
        np.save(savefile, single_params)
config = {
# FLAME
'flame_model_path': '/data/share/FLAME/Photometric_fitting/photometric_optimization/data/generic_model.pkl',  # acquire it from FLAME project page
'flame_lmk_embedding_path': '/data/share/FLAME/Photometric_fitting/photometric_optimization/data/landmark_embedding.npy',
'tex_space_path': '/data/share/FLAME/Photometric_fitting/photometric_optimization/data/FLAME_texture.npz',  # acquire it from FLAME project page
'camera_params': 3,
'shape_params': 100,
'expression_params': 50,
'pose_params': 6,
'tex_params': 50,
'use_face_contour': True,

'cropped_size': 256,
'batch_size': 1,
'image_size': 224,
'e_lr': 0.005,
'e_wd': 0.0001,
'savefolder': '/data/share/FLAME/facescape_fit/fit_results',
# weights of losses and reg terms
'w_pho': 8,
'w_lmks': 1,
'w_shape_reg': 1e-4,
'w_expr_reg': 1e-4,
'w_pose_reg': 0,
}

config = util.dict2obj(config)
util.check_mkdir(config.savefolder)
device_name = "cuda"
config.batch_size = 1
fitting = PhotometricFitting(config, device=device_name)
# Out:
# creating the FLAME Decoder
# /data/share/FLAME/Photometric_fitting/photometric_optimization/models/FLAME.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('dynamic_lmk_faces_idx', torch.tensor(lmk_embeddings['dynamic_lmk_faces_idx'], dtype=torch.long))
# /data/share/FLAME/Photometric_fitting/photometric_optimization/models/FLAME.py:82: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('dynamic_lmk_bary_coords', torch.tensor(lmk_embeddings['dynamic_lmk_bary_coords'], dtype=self.dtype))
# /home/guest/anaconda3/envs/flame/lib/python3.8/site-packages/pytorch3d/io/obj_io.py:457: UserWarning: Mtl file does not exist: /data/share/FLAME/Photometric_fitting/photometric_optimization/data/template.mtl
#   warnings.warn(f"Mtl file does not exist: {f}")

# %%
input_folder = '/data/share/FLAME/facescape_fit/images'
landmark_folder = '/data/share/FLAME/facescape_fit/landmarks'
image_mask_folder = '/data/share/FLAME/facescape_fit/masks'

for image_name in tqdm(os.listdir(input_folder)):
    image_name = image_name.split("/")[-1][:-4]
    imagepath = os.path.sep.join([input_folder, image_name + '.jpg'])
    landmarkpath = os.path.sep.join([landmark_folder, image_name + '.npy'])
    try:
        fitting.run(imagepath, landmarkpath,image_mask_folder)
    except:
        print("error in fitting {}".format(image_name))
        continue
# Out:
# ----iter: 0, time: 2023-07-03-16:22:54
# landmark: 4.442091941833496, all_loss: 4.442091941833496,
# ----iter: 10, time: 2023-07-03-16:22:54
# landmark: 4.025257110595703, all_loss: 4.025257110595703,
# ----iter: 20, time: 2023-07-03-16:22:54
# landmark: 3.6009929180145264, all_loss: 3.6009929180145264,
# ----iter: 30, time: 2023-07-03-16:22:54
# landmark: 3.1705591678619385, all_loss: 3.1705591678619385,
# ----iter: 40, time: 2023-07-03-16:22:54
# landmark: 2.737680673599243, all_loss: 2.737680673599243,
# ----iter: 50, time: 2023-07-03-16:22:54
# landmark: 2.3095719814300537, all_loss: 2.3095719814300537,
# ----iter: 60, time: 2023-07-03-16:22:54
# landmark: 1.9003210067749023, all_loss: 1.9003210067749023,
# ----iter: 70, time: 2023-07-03-16:22:54
# landmark: 1.536821961402893, all_loss: 1.536821961402893,
# ----iter: 80, time: 2023-07-03-16:22:54
# landmark: 1.2615820169448853, all_loss: 1.2615820169448853,
# ----iter: 90, time: 2023-07-03-16:22:55
# landmark: 1.1077897548675537, all_loss: 1.1077897548675537,
# ----iter: 100, time: 2023-07-03-16:22:55
# landmark: 1.042712926864624, all_loss: 1.042712926864624,
# ----iter: 110, time: 2023-07-03-16:22:55
# landmark: 1.006740927696228, all_loss: 1.006740927696228,
# ----iter: 120, time: 2023-07-03-16:22:55
# landmark: 0.9854929447174072, all_loss: 0.9854929447174072,
# ----iter: 130, time: 2023-07-03-16:22:55
# landmark: 0.9730316400527954, all_loss: 0.9730316400527954,
# ----iter: 140, time: 2023-07-03-16:22:55
# landmark: 0.9656704664230347, all_loss: 0.9656704664230347,
# ----iter: 150, time: 2023-07-03-16:22:55
# landmark: 0.9610098004341125, all_loss: 0.9610098004341125,
# ----iter: 160, time: 2023-07-03-16:22:55
# landmark: 0.9576547741889954, all_loss: 0.9576547741889954,
# ----iter: 170, time: 2023-07-03-16:22:55
# landmark: 0.955165445804596, all_loss: 0.955165445804596,
# ----iter: 180, time: 2023-07-03-16:22:55
# landmark: 0.9531528353691101, all_loss: 0.9531528353691101,
# ----iter: 190, time: 2023-07-03-16:22:55
# landmark: 0.951431393623352, all_loss: 0.951431393623352,
# ----iter: 200, time: 2023-07-03-16:22:55
# landmark: 1.1632145643234253, shape_reg: 0.0, expression_reg: 0.0, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.2586366985885347,
# directional
# ----iter: 210, time: 2023-07-03-16:22:56
# landmark: 1.134712815284729, shape_reg: 8.075438017840497e-06, expression_reg: 5.393668288888875e-06, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.2301484201995576,
# directional
# ----iter: 220, time: 2023-07-03-16:22:56
# landmark: 1.120737910270691, shape_reg: 2.981349462061189e-05, expression_reg: 2.0231047528795898e-05, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.2162101124374116,
# directional
# ----iter: 230, time: 2023-07-03-16:22:56
# landmark: 1.1094107627868652, shape_reg: 6.806028977734968e-05, expression_reg: 4.437050665728748e-05, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.204945311412021,
# directional
# ----iter: 240, time: 2023-07-03-16:22:56
# landmark: 1.0983664989471436, shape_reg: 0.00012171980051789433, expression_reg: 7.581741374451667e-05, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.1939861630050386,
# directional
# ----iter: 250, time: 2023-07-03-16:22:56
# landmark: 1.0870987176895142, shape_reg: 0.000189337064512074, expression_reg: 0.00011312399874441326, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.182823285922214,
# directional
# ----iter: 260, time: 2023-07-03-16:22:56
# landmark: 1.075545072555542, shape_reg: 0.00026928671286441386, expression_reg: 0.0001548388972878456, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.171391353472873,
# directional
# ----iter: 270, time: 2023-07-03-16:22:57
# landmark: 1.0636568069458008, shape_reg: 0.00035978725645691156, expression_reg: 0.00019960019562859088, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.1596382711974824,
# directional
# ----iter: 280, time: 2023-07-03-16:22:57
# landmark: 1.0515108108520508, shape_reg: 0.00045929744374006987, expression_reg: 0.0002460424439050257, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.147638306483432,
# directional
# ----iter: 290, time: 2023-07-03-16:22:57
# landmark: 1.0390938520431519, shape_reg: 0.0005664002965204418, expression_reg: 0.000293537275865674, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.135375842913791,
# directional
# ----iter: 300, time: 2023-07-03-16:22:57
# landmark: 1.0265617370605469, shape_reg: 0.0006790126790292561, expression_reg: 0.0003425107861403376, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.123005375727817,
# directional
# ----iter: 310, time: 2023-07-03-16:22:57
# landmark: 1.0140337944030762, shape_reg: 0.0007946326513774693, expression_reg: 0.00039329833816736937, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.110643849238559,
# directional
# ----iter: 320, time: 2023-07-03-16:22:57
# landmark: 1.0013819932937622, shape_reg: 0.0009136121370829642, expression_reg: 0.0004464155063033104, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.0981641863433564,
# directional
# ----iter: 330, time: 2023-07-03-16:22:58
# landmark: 0.9883930087089539, shape_reg: 0.0010395677527412772, expression_reg: 0.0005015847273170948, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.0853562806693757,
# directional
# ----iter: 340, time: 2023-07-03-16:22:58
# landmark: 0.9755802154541016, shape_reg: 0.0011743985814973712, expression_reg: 0.0005582274170592427, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.0727349971381868,
# directional
# ----iter: 350, time: 2023-07-03-16:22:58
# landmark: 0.9633426666259766, shape_reg: 0.0013151686871424317, expression_reg: 0.0006166744278743863, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.060696647032901,
# directional
# ----iter: 360, time: 2023-07-03-16:22:58
# landmark: 0.9517582058906555, shape_reg: 0.001456999802030623, expression_reg: 0.0006770993932150304, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.049314424857303,
# directional
# ----iter: 370, time: 2023-07-03-16:22:58
# landmark: 0.9403021335601807, shape_reg: 0.0015961385797709227, expression_reg: 0.0007390249520540237, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.0380594585983003,
# directional
# ----iter: 380, time: 2023-07-03-16:22:59
# landmark: 0.9290980100631714, shape_reg: 0.0017313536955043674, expression_reg: 0.0008027192670851946, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.0270541761962617,
# directional
# ----iter: 390, time: 2023-07-03-16:22:59
# landmark: 0.9182034730911255, shape_reg: 0.0018629173282533884, expression_reg: 0.0008685230277478695, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.016357049807712,
# directional
# ----iter: 400, time: 2023-07-03-16:22:59
# landmark: 0.9080215096473694, shape_reg: 0.001991769764572382, expression_reg: 0.0009355993825010955, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 2.0063710068313325,
# directional
# ----iter: 410, time: 2023-07-03-16:22:59
# landmark: 0.8994266390800476, shape_reg: 0.002118786098435521, expression_reg: 0.001002925680950284, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9979704474059783,
# directional
# ----iter: 420, time: 2023-07-03-16:22:59
# landmark: 0.8913086652755737, shape_reg: 0.002244501141831279, expression_reg: 0.0010702642612159252, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.990045533045932,
# directional
# ----iter: 430, time: 2023-07-03-16:22:59
# landmark: 0.8837891817092896, shape_reg: 0.002370328875258565, expression_reg: 0.0011376048205420375, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9827192877380095,
# directional
# ----iter: 440, time: 2023-07-03-16:23:00
# landmark: 0.8766170144081116, shape_reg: 0.0024978560395538807, expression_reg: 0.001205466571263969, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9757424448577605,
# directional
# ----iter: 450, time: 2023-07-03-16:23:00
# landmark: 0.8696082830429077, shape_reg: 0.002627893816679716, expression_reg: 0.0012743143597617745, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9689326141921721,
# directional
# ----iter: 460, time: 2023-07-03-16:23:00
# landmark: 0.8629159331321716, shape_reg: 0.0027607670053839684, expression_reg: 0.00134428555611521, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9624430988876067,
# directional
# ----iter: 470, time: 2023-07-03-16:23:00
# landmark: 0.8562249541282654, shape_reg: 0.002896689111366868, expression_reg: 0.001415311242453754, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9559590672103606,
# directional
# ----iter: 480, time: 2023-07-03-16:23:00
# landmark: 0.8498336672782898, shape_reg: 0.003035701811313629, expression_reg: 0.0014873351901769638, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9497788404075347,
# directional
# ----iter: 490, time: 2023-07-03-16:23:00
# landmark: 0.843509316444397, shape_reg: 0.0031778737902641296, expression_reg: 0.0015603950014337897, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9436697219459258,
# directional
# ----iter: 500, time: 2023-07-03-16:23:01
# landmark: 0.8371375799179077, shape_reg: 0.00332316430285573, expression_reg: 0.0016345515614375472, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9375173901168548,
# directional
# ----iter: 510, time: 2023-07-03-16:23:01
# landmark: 0.8308859467506409, shape_reg: 0.0034716404043138027, expression_reg: 0.0017098765820264816, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9314895723907195,
# directional
# ----iter: 520, time: 2023-07-03-16:23:01
# landmark: 0.8247315883636475, shape_reg: 0.003623177297413349, expression_reg: 0.0017864436376839876, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9255633805839263,
# directional
# ----iter: 530, time: 2023-07-03-16:23:01
# landmark: 0.8185577988624573, shape_reg: 0.0037777803372591734, expression_reg: 0.0018643419025465846, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9196220491973601,
# directional
# ----iter: 540, time: 2023-07-03-16:23:01
# landmark: 0.8124156594276428, shape_reg: 0.003935311920940876, expression_reg: 0.0019436522852629423, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.913716778620883,
# directional
# ----iter: 550, time: 2023-07-03-16:23:01
# landmark: 0.8062784075737, shape_reg: 0.004095732234418392, expression_reg: 0.0020244463812559843, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9078207467643462,
# directional
# ----iter: 560, time: 2023-07-03-16:23:02
# landmark: 0.8000905513763428, shape_reg: 0.004259012173861265, expression_reg: 0.002106806030496955, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.9018784617034636,
# directional
# ----iter: 570, time: 2023-07-03-16:23:02
# landmark: 0.7939656376838684, shape_reg: 0.004425046965479851, expression_reg: 0.0021907661575824022, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.896003589495822,
# directional
# ----iter: 580, time: 2023-07-03-16:23:02
# landmark: 0.7878167629241943, shape_reg: 0.00459378631785512, expression_reg: 0.002276371233165264, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8901090477554046,
# directional
# ----iter: 590, time: 2023-07-03-16:23:02
# landmark: 0.7817884087562561, shape_reg: 0.0047651901841163635, expression_reg: 0.002363658742979169, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8843394373504363,
# directional
# ----iter: 600, time: 2023-07-03-16:23:02
# landmark: 0.7756091952323914, shape_reg: 0.004939213395118713, expression_reg: 0.0024526668712496758, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8784231995193206,
# directional
# ----iter: 610, time: 2023-07-03-16:23:02
# landmark: 0.7694430947303772, shape_reg: 0.005115757696330547, expression_reg: 0.0025434501003473997, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.872524425849124,
# directional
# ----iter: 620, time: 2023-07-03-16:23:03
# landmark: 0.763343334197998, shape_reg: 0.005294688045978546, expression_reg: 0.00263601983897388, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8666961644736968,
# directional
# ----iter: 630, time: 2023-07-03-16:23:03
# landmark: 0.7572560906410217, shape_reg: 0.00547579862177372, expression_reg: 0.0027305237017571926, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8608845923988067,
# directional
# ----iter: 640, time: 2023-07-03-16:23:03
# landmark: 0.750991702079773, shape_reg: 0.005658718757331371, expression_reg: 0.002827160991728306, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8548997496215545,
# directional
# ----iter: 650, time: 2023-07-03-16:23:03
# landmark: 0.7449595332145691, shape_reg: 0.005843059159815311, expression_reg: 0.0029262707103043795, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8491510008422576,
# directional
# ----iter: 660, time: 2023-07-03-16:23:03
# landmark: 0.7392072081565857, shape_reg: 0.006030020769685507, expression_reg: 0.0030285846441984177, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8436879371253692,
# directional
# ----iter: 670, time: 2023-07-03-16:23:03
# landmark: 0.7330121994018555, shape_reg: 0.006219991948455572, expression_reg: 0.003133720252662897, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.837788030966922,
# directional
# ----iter: 680, time: 2023-07-03-16:23:04
# landmark: 0.7269855737686157, shape_reg: 0.006411303766071796, expression_reg: 0.0032425846438854933, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8320616339294158,
# directional
# ----iter: 690, time: 2023-07-03-16:23:04
# landmark: 0.7210230231285095, shape_reg: 0.0066046095453202724, expression_reg: 0.0033528441563248634, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8264025901405059,
# directional
# ----iter: 700, time: 2023-07-03-16:23:04
# landmark: 0.7151676416397095, shape_reg: 0.006802572403103113, expression_reg: 0.003463917877525091, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8208562587348662,
# directional
# ----iter: 710, time: 2023-07-03-16:23:04
# landmark: 0.7092098593711853, shape_reg: 0.0070049213245511055, expression_reg: 0.003576851449906826, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.8152137850372039,
# directional
# ----iter: 720, time: 2023-07-03-16:23:04
# landmark: 0.7031601071357727, shape_reg: 0.007211740594357252, expression_reg: 0.0036917056422680616, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.809485719069644,
# directional
# ----iter: 730, time: 2023-07-03-16:23:04
# landmark: 0.6972910761833191, shape_reg: 0.0074227857403457165, expression_reg: 0.0038080362137407064, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.803944036826297,
# directional
# ----iter: 740, time: 2023-07-03-16:23:05
# landmark: 0.6912748217582703, shape_reg: 0.007637741044163704, expression_reg: 0.003925931639969349, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7982606147376738,
# directional
# ----iter: 750, time: 2023-07-03-16:23:05
# landmark: 0.685217559337616, shape_reg: 0.007856360636651516, expression_reg: 0.004045612644404173, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7925416682807647,
# directional
# ----iter: 760, time: 2023-07-03-16:23:05
# landmark: 0.6792333722114563, shape_reg: 0.008078408427536488, expression_reg: 0.004166992846876383, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7869009231178008,
# directional
# ----iter: 770, time: 2023-07-03-16:23:05
# landmark: 0.6732497215270996, shape_reg: 0.0083038080483675, expression_reg: 0.004290086217224598, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7812657807914458,
# directional
# ----iter: 780, time: 2023-07-03-16:23:05
# landmark: 0.6672115325927734, shape_reg: 0.00853245984762907, expression_reg: 0.004414907656610012, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7755810474006377,
# directional
# ----iter: 790, time: 2023-07-03-16:23:05
# landmark: 0.6610551476478577, shape_reg: 0.008764337748289108, expression_reg: 0.004541472066193819, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7697830651847564,
# directional
# ----iter: 800, time: 2023-07-03-16:23:05
# landmark: 0.6549362540245056, shape_reg: 0.008999407291412354, expression_reg: 0.004669818561524153, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7640276406852446,
# directional
# ----iter: 810, time: 2023-07-03-16:23:06
# landmark: 0.6488665342330933, shape_reg: 0.009237623773515224, expression_reg: 0.004799936432391405, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7583262775985442,
# directional
# ----iter: 820, time: 2023-07-03-16:23:06
# landmark: 0.6427614688873291, shape_reg: 0.009478915482759476, expression_reg: 0.00493178004398942, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.752594337329074,
# directional
# ----iter: 830, time: 2023-07-03-16:23:06
# landmark: 0.6366172432899475, shape_reg: 0.009723259136080742, expression_reg: 0.005065352655947208, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7468280051795684,
# directional
# ----iter: 840, time: 2023-07-03-16:23:06
# landmark: 0.6304622888565063, shape_reg: 0.009970624931156635, expression_reg: 0.005200705491006374, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7410557125655852,
# directional
# ----iter: 850, time: 2023-07-03-16:23:06
# landmark: 0.6243510842323303, shape_reg: 0.010220999829471111, expression_reg: 0.005337812472134829, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7353320573417388,
# directional
# ----iter: 860, time: 2023-07-03-16:23:06
# landmark: 0.6181767582893372, shape_reg: 0.010474256239831448, expression_reg: 0.005476546473801136, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7295496915427886,
# directional
# ----iter: 870, time: 2023-07-03-16:23:07
# landmark: 0.6119983792304993, shape_reg: 0.010730364359915257, expression_reg: 0.005616882815957069, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7237678025809966,
# directional
# ----iter: 880, time: 2023-07-03-16:23:07
# landmark: 0.6057396531105042, shape_reg: 0.01098924595862627, expression_reg: 0.005758742801845074, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7179097984878264,
# directional
# ----iter: 890, time: 2023-07-03-16:23:07
# landmark: 0.5996109843254089, shape_reg: 0.01125088520348072, expression_reg: 0.005902110133320093, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.71218614326398,
# directional
# ----iter: 900, time: 2023-07-03-16:23:07
# landmark: 0.5933631658554077, shape_reg: 0.011515173129737377, expression_reg: 0.00604696199297905, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.706347451075717,
# directional
# ----iter: 910, time: 2023-07-03-16:23:07
# landmark: 0.5872347354888916, shape_reg: 0.011782078072428703, expression_reg: 0.0061930143274366856, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.7006319616882049,
# directional
# ----iter: 920, time: 2023-07-03-16:23:07
# landmark: 0.581037163734436, shape_reg: 0.012051355093717575, expression_reg: 0.0063401153311133385, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.6948507283775054,
# directional
# ----iter: 930, time: 2023-07-03-16:23:08
# landmark: 0.5748387575149536, shape_reg: 0.012323004193603992, expression_reg: 0.0064880321733653545, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.6890719388572417,
# directional
# ----iter: 940, time: 2023-07-03-16:23:08
# landmark: 0.5685574412345886, shape_reg: 0.012596790678799152, expression_reg: 0.006636214908212423, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.6832125638572417,
# directional
# ----iter: 950, time: 2023-07-03-16:23:08
# landmark: 0.5624403357505798, shape_reg: 0.012872547842562199, expression_reg: 0.00678360415622592, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.6775186513511382,
# directional
# ----iter: 960, time: 2023-07-03-16:23:08
# landmark: 0.5567250847816467, shape_reg: 0.013150106184184551, expression_reg: 0.006927005015313625, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.672224328383609,
# directional
# ----iter: 970, time: 2023-07-03-16:23:08
# landmark: 0.5501937866210938, shape_reg: 0.01342819444835186, expression_reg: 0.007063047494739294, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.6661071632949553,
# directional
# ----iter: 980, time: 2023-07-03-16:23:08
# landmark: 0.5444091558456421, shape_reg: 0.01370781660079956, expression_reg: 0.007197851315140724, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.660736963614627,
# directional
# ----iter: 990, time: 2023-07-03-16:23:08
# landmark: 0.5383406281471252, shape_reg: 0.013988502323627472, expression_reg: 0.007329615764319897, pose_reg: 0.0, photometric_texture: 1.0954221342651091, all_loss: 1.6550809000579558,
# directional
# making /data/share/FLAME/facescape_fit/fit_results/186_3_mouth_stretch_8_yaw_(65,90)
# ----iter: 0, time: 2023-07-03-16:23:09
# landmark: 4.631979942321777, all_loss: 4.631979942321777,
# ----iter: 10, time: 2023-07-03-16:23:10
# landmark: 4.210086345672607, all_loss: 4.210086345672607,
# ----iter: 20, time: 2023-07-03-16:23:10
# landmark: 3.7791006565093994, all_loss: 3.7791006565093994,
# ----iter: 30, time: 2023-07-03-16:23:10
# landmark: 3.3393847942352295, all_loss: 3.3393847942352295,
# ----iter: 40, time: 2023-07-03-16:23:10
# landmark: 2.893174886703491, all_loss: 2.893174886703491,
# ----iter: 50, time: 2023-07-03-16:23:10
# landmark: 2.4454634189605713, all_loss: 2.4454634189605713,
# ----iter: 60, time: 2023-07-03-16:23:10
# landmark: 2.006570339202881, all_loss: 2.006570339202881,
# ----iter: 70, time: 2023-07-03-16:23:10
# landmark: 1.598886251449585, all_loss: 1.598886251449585,
# ----iter: 80, time: 2023-07-03-16:23:10
# landmark: 1.2684234380722046, all_loss: 1.2684234380722046,
# ----iter: 90, time: 2023-07-03-16:23:10
# landmark: 1.0824347734451294, all_loss: 1.0824347734451294,
# ----iter: 100, time: 2023-07-03-16:23:10
# landmark: 1.0166085958480835, all_loss: 1.0166085958480835,
# ----iter: 110, time: 2023-07-03-16:23:10
# landmark: 0.9862743020057678, all_loss: 0.9862743020057678,
# ----iter: 120, time: 2023-07-03-16:23:10
# landmark: 0.9696434736251831, all_loss: 0.9696434736251831,
# ----iter: 130, time: 2023-07-03-16:23:10
# landmark: 0.9596531987190247, all_loss: 0.9596531987190247,
# ----iter: 140, time: 2023-07-03-16:23:11
# landmark: 0.9539545178413391, all_loss: 0.9539545178413391,
# ----iter: 150, time: 2023-07-03-16:23:11
# landmark: 0.9504052400588989, all_loss: 0.9504052400588989,
# ----iter: 160, time: 2023-07-03-16:23:11
# landmark: 0.9479639530181885, all_loss: 0.9479639530181885,
# ----iter: 170, time: 2023-07-03-16:23:11
# landmark: 0.9459366202354431, all_loss: 0.9459366202354431,
# ----iter: 180, time: 2023-07-03-16:23:11
# landmark: 0.9442195892333984, all_loss: 0.9442195892333984,
# ----iter: 190, time: 2023-07-03-16:23:11
# landmark: 0.9427145719528198, all_loss: 0.9427145719528198,
# ----iter: 200, time: 2023-07-03-16:23:11
# landmark: 1.1550203561782837, shape_reg: 0.0, expression_reg: 0.0, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 2.0662075451000783,
# directional
# ----iter: 210, time: 2023-07-03-16:23:11
# landmark: 1.1214210987091064, shape_reg: 8.444169907306787e-06, expression_reg: 5.465324193210108e-06, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 2.0326222351177785,
# directional
# ----iter: 220, time: 2023-07-03-16:23:11
# landmark: 1.1065795421600342, shape_reg: 3.0291217626654543e-05, expression_reg: 2.0672452592407353e-05, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 2.017817633448467,
# directional
# ----iter: 230, time: 2023-07-03-16:23:12
# landmark: 1.0937150716781616, shape_reg: 6.8325360189192e-05, expression_reg: 4.514278771239333e-05, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 2.0050157478436086,
# directional
# ----iter: 240, time: 2023-07-03-16:23:12
# landmark: 1.0810539722442627, shape_reg: 0.00012141970364609733, expression_reg: 7.728631317149848e-05, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.9924398830517385,
# directional
# ----iter: 250, time: 2023-07-03-16:23:12
# landmark: 1.0680155754089355, shape_reg: 0.00018803907732944936, expression_reg: 0.00011545660527190194, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.9795062711819265,
# directional
# ----iter: 260, time: 2023-07-03-16:23:12
# landmark: 1.0544383525848389, shape_reg: 0.00026658509159460664, expression_reg: 0.0001578029477968812, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.9660499265774343,
# directional
# ----iter: 270, time: 2023-07-03-16:23:12
# landmark: 1.0406635999679565, shape_reg: 0.00035562427365221083, expression_reg: 0.00020258218864910305, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.952408926783428,
# directional
# ----iter: 280, time: 2023-07-03-16:23:12
# landmark: 1.026496410369873, shape_reg: 0.000453317683422938, expression_reg: 0.0002492820785846561, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.93838621884428,
# directional
# ----iter: 290, time: 2023-07-03-16:23:13
# landmark: 1.0121177434921265, shape_reg: 0.000557084335014224, expression_reg: 0.00029815768357366323, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.9241601398571584,
# directional
# ----iter: 300, time: 2023-07-03-16:23:13
# landmark: 0.9974039793014526, shape_reg: 0.0006652246229350567, expression_reg: 0.00034920391044579446, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.9096056392773244,
# directional
# ----iter: 310, time: 2023-07-03-16:23:13
# landmark: 0.9826532006263733, shape_reg: 0.0007790272356942296, expression_reg: 0.00040264957351610065, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.89502205163084,
# directional
# ----iter: 320, time: 2023-07-03-16:23:13
# landmark: 0.9674209356307983, shape_reg: 0.0009024537866935134, expression_reg: 0.00045876417425461113, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.8799693754299733,
# directional
# ----iter: 330, time: 2023-07-03-16:23:13
# landmark: 0.9521855711936951, shape_reg: 0.0010380306048318744, expression_reg: 0.0005168640054762363, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.8649276664837453,
# directional
# ----iter: 340, time: 2023-07-03-16:23:13
# landmark: 0.9374342560768127, shape_reg: 0.0011837129713967443, expression_reg: 0.0005762986838817596, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.850381450949535,
# directional
# ----iter: 350, time: 2023-07-03-16:23:14
# landmark: 0.923443078994751, shape_reg: 0.0013352088863030076, expression_reg: 0.0006366122979670763, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.836602108775005,
# directional
# ----iter: 360, time: 2023-07-03-16:23:14
# landmark: 0.9093809723854065, shape_reg: 0.0014893714105710387, expression_reg: 0.0006975398282520473, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.822755115328655,
# directional
# ----iter: 370, time: 2023-07-03-16:23:14
# landmark: 0.8956634402275085, shape_reg: 0.0016450174152851105, expression_reg: 0.0007600352982990444, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.8092556765659902,
# directional
# ----iter: 380, time: 2023-07-03-16:23:14
# landmark: 0.8816982507705688, shape_reg: 0.0018009650520980358, expression_reg: 0.0008249125094152987, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7955113223179433,
# directional
# ----iter: 390, time: 2023-07-03-16:23:14
# landmark: 0.8694605231285095, shape_reg: 0.001956287072971463, expression_reg: 0.000892082171048969, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7834960988148305,
# directional
# ----iter: 400, time: 2023-07-03-16:23:14
# landmark: 0.8587353825569153, shape_reg: 0.002110367175191641, expression_reg: 0.0009607509127818048, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.772993700800762,
# directional
# ----iter: 410, time: 2023-07-03-16:23:15
# landmark: 0.8485240936279297, shape_reg: 0.0022633105982095003, expression_reg: 0.0010299599962309003, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7630045583828542,
# directional
# ----iter: 420, time: 2023-07-03-16:23:15
# landmark: 0.8392220735549927, shape_reg: 0.0024162749759852886, expression_reg: 0.001098931417800486, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.753924446402416,
# directional
# ----iter: 430, time: 2023-07-03-16:23:15
# landmark: 0.830396294593811, shape_reg: 0.002570154843851924, expression_reg: 0.0011680973693728447, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7453217080219838,
# directional
# ----iter: 440, time: 2023-07-03-16:23:15
# landmark: 0.8220473527908325, shape_reg: 0.0027249883860349655, expression_reg: 0.00123810232616961, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7371976545437429,
# directional
# ----iter: 450, time: 2023-07-03-16:23:15
# landmark: 0.81412672996521, shape_reg: 0.002880588173866272, expression_reg: 0.0013091684086248279, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7295036485775563,
# directional
# ----iter: 460, time: 2023-07-03-16:23:15
# landmark: 0.8064827919006348, shape_reg: 0.003036751877516508, expression_reg: 0.0013812268152832985, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7220879366978261,
# directional
# ----iter: 470, time: 2023-07-03-16:23:16
# landmark: 0.7990962862968445, shape_reg: 0.0031934776343405247, expression_reg: 0.001454210956580937, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.714931206999645,
# directional
# ----iter: 480, time: 2023-07-03-16:23:16
# landmark: 0.7919659614562988, shape_reg: 0.0033507358748465776, expression_reg: 0.0015281692612916231, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7080320289715383,
# directional
# ----iter: 490, time: 2023-07-03-16:23:16
# landmark: 0.7850295305252075, shape_reg: 0.0035086050629615784, expression_reg: 0.0016031581908464432, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.7013285329922292,
# directional
# ----iter: 500, time: 2023-07-03-16:23:16
# landmark: 0.7782827019691467, shape_reg: 0.003667176002636552, expression_reg: 0.0016792332753539085, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6948163083180043,
# directional
# ----iter: 510, time: 2023-07-03-16:23:16
# landmark: 0.7716311812400818, shape_reg: 0.003826531581580639, expression_reg: 0.0017563857836648822, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6884012988194081,
# directional
# ----iter: 520, time: 2023-07-03-16:23:16
# landmark: 0.765088677406311, shape_reg: 0.003986726049333811, expression_reg: 0.0018346399301663041, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.682097213564739,
# directional
# ----iter: 530, time: 2023-07-03-16:23:17
# landmark: 0.758709728717804, shape_reg: 0.004147905856370926, expression_reg: 0.0019140492659062147, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6759588292225454,
# directional
# ----iter: 540, time: 2023-07-03-16:23:17
# landmark: 0.7523480653762817, shape_reg: 0.004310152493417263, expression_reg: 0.0019946300890296698, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.669839995203838,
# directional
# ----iter: 550, time: 2023-07-03-16:23:17
# landmark: 0.7460978031158447, shape_reg: 0.004473486915230751, expression_reg: 0.0020764123182743788, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6638348868473622,
# directional
# ----iter: 560, time: 2023-07-03-16:23:17
# landmark: 0.739854633808136, shape_reg: 0.004638069774955511, expression_reg: 0.0021594478748738766, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6578393748386953,
# directional
# ----iter: 570, time: 2023-07-03-16:23:17
# landmark: 0.7337400913238525, shape_reg: 0.004803872667253017, expression_reg: 0.002243766328319907, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6519749334438893,
# directional
# ----iter: 580, time: 2023-07-03-16:23:17
# landmark: 0.7275329232215881, shape_reg: 0.004970991984009743, expression_reg: 0.002329409820958972, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6460204890354726,
# directional
# ----iter: 590, time: 2023-07-03-16:23:18
# landmark: 0.7214208245277405, shape_reg: 0.005139513872563839, expression_reg: 0.0024164041969925165, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6401639750584218,
# directional
# ----iter: 600, time: 2023-07-03-16:23:18
# landmark: 0.7153826951980591, shape_reg: 0.005309453699737787, expression_reg: 0.0025047657545655966, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6343841126545522,
# directional
# ----iter: 610, time: 2023-07-03-16:23:18
# landmark: 0.7092512845993042, shape_reg: 0.005480860825628042, expression_reg: 0.0025945077650249004, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.628513889609203,
# directional
# ----iter: 620, time: 2023-07-03-16:23:18
# landmark: 0.7031843662261963, shape_reg: 0.005653822794556618, expression_reg: 0.002685672603547573, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6227110198124501,
# directional
# ----iter: 630, time: 2023-07-03-16:23:18
# landmark: 0.6972140669822693, shape_reg: 0.0058284117840230465, expression_reg: 0.00277826189994812, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.617007987795696,
# directional
# ----iter: 640, time: 2023-07-03-16:23:18
# landmark: 0.6911075711250305, shape_reg: 0.006004753522574902, expression_reg: 0.002872264478355646, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.6111717990025136,
# directional
# ----iter: 650, time: 2023-07-03-16:23:19
# landmark: 0.6851483583450317, shape_reg: 0.006182865705341101, expression_reg: 0.0029676882550120354, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.605486111937389,
# directional
# ----iter: 660, time: 2023-07-03-16:23:19
# landmark: 0.6790491938591003, shape_reg: 0.0063628628849983215, expression_reg: 0.0030645346269011497, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5996637514217946,
# directional
# ----iter: 670, time: 2023-07-03-16:23:19
# landmark: 0.6730883717536926, shape_reg: 0.0065448591485619545, expression_reg: 0.00316278962418437, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5939832499607656,
# directional
# ----iter: 680, time: 2023-07-03-16:23:19
# landmark: 0.6670424342155457, shape_reg: 0.006728938315063715, expression_reg: 0.0032623999286442995, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5882209709271047,
# directional
# ----iter: 690, time: 2023-07-03-16:23:19
# landmark: 0.6609523892402649, shape_reg: 0.006915183737874031, expression_reg: 0.0033633308485150337, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5824181011303518,
# directional
# ----iter: 700, time: 2023-07-03-16:23:19
# landmark: 0.6550211310386658, shape_reg: 0.007103633135557175, expression_reg: 0.003465564688667655, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5767775347813222,
# directional
# ----iter: 710, time: 2023-07-03-16:23:20
# landmark: 0.6488951444625854, shape_reg: 0.007294390816241503, expression_reg: 0.0035690623335540295, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.570945816336498,
# directional
# ----iter: 720, time: 2023-07-03-16:23:20
# landmark: 0.6428847312927246, shape_reg: 0.0074875736609101295, expression_reg: 0.0036737548653036356, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5652332475765798,
# directional
# ----iter: 730, time: 2023-07-03-16:23:20
# landmark: 0.6369031071662903, shape_reg: 0.0076831914484500885, expression_reg: 0.003779585938900709, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5595531037434194,
# directional
# ----iter: 740, time: 2023-07-03-16:23:20
# landmark: 0.6308035254478455, shape_reg: 0.007881269790232182, expression_reg: 0.003886529477313161, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5537585189922902,
# directional
# ----iter: 750, time: 2023-07-03-16:23:20
# landmark: 0.624793291091919, shape_reg: 0.0080818310379982, expression_reg: 0.003994507249444723, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.548056857882366,
# directional
# ----iter: 760, time: 2023-07-03-16:23:20
# landmark: 0.618740975856781, shape_reg: 0.008284999057650566, expression_reg: 0.004103424493223429, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5423165729626271,
# directional
# ----iter: 770, time: 2023-07-03-16:23:21
# landmark: 0.6127005219459534, shape_reg: 0.008490746840834618, expression_reg: 0.004213238134980202, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5365916660412404,
# directional
# ----iter: 780, time: 2023-07-03-16:23:21
# landmark: 0.6065987348556519, shape_reg: 0.00869905948638916, expression_reg: 0.004323843866586685, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.530808823405132,
# directional
# ----iter: 790, time: 2023-07-03-16:23:21
# landmark: 0.6005944609642029, shape_reg: 0.00891003105789423, expression_reg: 0.004435164388269186, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5251268914326284,
# directional
# ----iter: 800, time: 2023-07-03-16:23:21
# landmark: 0.5946425795555115, shape_reg: 0.009123562835156918, expression_reg: 0.00454706372693181, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5195003917797658,
# directional
# ----iter: 810, time: 2023-07-03-16:23:21
# landmark: 0.5885974168777466, shape_reg: 0.009339720010757446, expression_reg: 0.004659400321543217, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.513783710299358,
# directional
# ----iter: 820, time: 2023-07-03-16:23:21
# landmark: 0.5825859308242798, shape_reg: 0.009558488614857197, expression_reg: 0.004772075917571783, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5081036856754872,
# directional
# ----iter: 830, time: 2023-07-03-16:23:22
# landmark: 0.5766260623931885, shape_reg: 0.009779825806617737, expression_reg: 0.0048848907463252544, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.5024779608830068,
# directional
# ----iter: 840, time: 2023-07-03-16:23:22
# landmark: 0.5707149505615234, shape_reg: 0.010003631003201008, expression_reg: 0.004997675772756338, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4969034364803884,
# directional
# ----iter: 850, time: 2023-07-03-16:23:22
# landmark: 0.5646249055862427, shape_reg: 0.010229930281639099, expression_reg: 0.005110356491059065, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.49115242272459,
# directional
# ----iter: 860, time: 2023-07-03-16:23:22
# landmark: 0.5587059259414673, shape_reg: 0.010458610951900482, expression_reg: 0.005222861189395189, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4855745604618642,
# directional
# ----iter: 870, time: 2023-07-03-16:23:22
# landmark: 0.5528296232223511, shape_reg: 0.010689648799598217, expression_reg: 0.005335111636668444, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4800415804966542,
# directional
# ----iter: 880, time: 2023-07-03-16:23:22
# landmark: 0.546917200088501, shape_reg: 0.010922960937023163, expression_reg: 0.005447103641927242, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.474474447069988,
# directional
# ----iter: 890, time: 2023-07-03-16:23:23
# landmark: 0.5410818457603455, shape_reg: 0.011158544570207596, expression_reg: 0.0055589256808161736, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4689864686115834,
# directional
# ----iter: 900, time: 2023-07-03-16:23:23
# landmark: 0.5352584719657898, shape_reg: 0.011396266520023346, expression_reg: 0.005670648068189621, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4635126164539907,
# directional
# ----iter: 910, time: 2023-07-03-16:23:23
# landmark: 0.5294280052185059, shape_reg: 0.011636059731245041, expression_reg: 0.005782405845820904, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.458033697901592,
# directional
# ----iter: 920, time: 2023-07-03-16:23:23
# landmark: 0.5235770344734192, shape_reg: 0.011877891607582569, expression_reg: 0.00589425815269351, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4525363615139577,
# directional
# ----iter: 930, time: 2023-07-03-16:23:23
# landmark: 0.5178336501121521, shape_reg: 0.012121659703552723, expression_reg: 0.006006345152854919, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4471488764866445,
# directional
# ----iter: 940, time: 2023-07-03-16:23:23
# landmark: 0.5120753049850464, shape_reg: 0.012367239221930504, expression_reg: 0.006118749734014273, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4417485168560598,
# directional
# ----iter: 950, time: 2023-07-03-16:23:23
# landmark: 0.5063579082489014, shape_reg: 0.012614518404006958, expression_reg: 0.006231388542801142, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4363909533604238,
# directional
# ----iter: 960, time: 2023-07-03-16:23:24
# landmark: 0.5005614757537842, shape_reg: 0.012863412499427795, expression_reg: 0.006344222463667393, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4309562614544484,
# directional
# ----iter: 970, time: 2023-07-03-16:23:24
# landmark: 0.4949411451816559, shape_reg: 0.013113793917000294, expression_reg: 0.006457111798226833, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4256991913899038,
# directional
# ----iter: 980, time: 2023-07-03-16:23:24
# landmark: 0.48932725191116333, shape_reg: 0.013365508988499641, expression_reg: 0.006569914054125547, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4204498699291799,
# directional
# ----iter: 990, time: 2023-07-03-16:23:24
# landmark: 0.48372745513916016, shape_reg: 0.013618458062410355, expression_reg: 0.006682348437607288, pose_reg: 0.0, photometric_texture: 0.9111871889217945, all_loss: 1.4152154496296498,
# directional
# making /data/share/FLAME/facescape_fit/fit_results/313_14_sadness_33_pitch_(-10,15)
# ----iter: 0, time: 2023-07-03-16:23:25
# landmark: 4.774216651916504, all_loss: 4.774216651916504,
# ----iter: 10, time: 2023-07-03-16:23:25
# landmark: 4.344461441040039, all_loss: 4.344461441040039,
# ----iter: 20, time: 2023-07-03-16:23:25
# landmark: 3.9039862155914307, all_loss: 3.9039862155914307,
# ----iter: 30, time: 2023-07-03-16:23:25
# landmark: 3.452622175216675, all_loss: 3.452622175216675,
# ----iter: 40, time: 2023-07-03-16:23:25
# landmark: 2.992088556289673, all_loss: 2.992088556289673,
# ----iter: 50, time: 2023-07-03-16:23:25
# landmark: 2.5274462699890137, all_loss: 2.5274462699890137,
# ----iter: 60, time: 2023-07-03-16:23:25
# landmark: 2.0721752643585205, all_loss: 2.0721752643585205,
# ----iter: 70, time: 2023-07-03-16:23:26
# landmark: 1.663068175315857, all_loss: 1.663068175315857,
# ----iter: 80, time: 2023-07-03-16:23:26
# landmark: 1.3705717325210571, all_loss: 1.3705717325210571,
# ----iter: 90, time: 2023-07-03-16:23:26
# landmark: 1.1885524988174438, all_loss: 1.1885524988174438,
# ----iter: 100, time: 2023-07-03-16:23:26
# landmark: 1.0888413190841675, all_loss: 1.0888413190841675,
# ----iter: 110, time: 2023-07-03-16:23:26
# landmark: 1.0418798923492432, all_loss: 1.0418798923492432,
# ----iter: 120, time: 2023-07-03-16:23:26
# landmark: 1.0185699462890625, all_loss: 1.0185699462890625,
# ----iter: 130, time: 2023-07-03-16:23:26
# landmark: 1.0069622993469238, all_loss: 1.0069622993469238,
# ----iter: 140, time: 2023-07-03-16:23:26
# landmark: 0.9995009899139404, all_loss: 0.9995009899139404,
# ----iter: 150, time: 2023-07-03-16:23:26
# landmark: 0.9947981238365173, all_loss: 0.9947981238365173,
# ----iter: 160, time: 2023-07-03-16:23:26
# landmark: 0.991534948348999, all_loss: 0.991534948348999,
# ----iter: 170, time: 2023-07-03-16:23:26
# landmark: 0.9883075952529907, all_loss: 0.9883075952529907,
# ----iter: 180, time: 2023-07-03-16:23:26
# landmark: 0.9848987460136414, all_loss: 0.9848987460136414,
# ----iter: 190, time: 2023-07-03-16:23:26
# landmark: 0.9814483523368835, all_loss: 0.9814483523368835,
# ----iter: 200, time: 2023-07-03-16:23:26
# landmark: 1.178479552268982, shape_reg: 0.0, expression_reg: 0.0, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.30944277841716,
# directional
# ----iter: 210, time: 2023-07-03-16:23:27
# landmark: 1.1464749574661255, shape_reg: 1.0731032489275094e-05, expression_reg: 5.939167749602348e-06, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.2774548729148405,
# directional
# ----iter: 220, time: 2023-07-03-16:23:27
# landmark: 1.1292356252670288, shape_reg: 3.7615060136886314e-05, expression_reg: 2.1468633349286392e-05, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.260257979222824,
# directional
# ----iter: 230, time: 2023-07-03-16:23:27
# landmark: 1.1139801740646362, shape_reg: 8.052957127802074e-05, expression_reg: 4.553445251076482e-05, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.245069523641159,
# directional
# ----iter: 240, time: 2023-07-03-16:23:27
# landmark: 1.0995742082595825, shape_reg: 0.00013789307558909059, expression_reg: 7.708757038926706e-05, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.23075248796611,
# directional
# ----iter: 250, time: 2023-07-03-16:23:27
# landmark: 1.0862571001052856, shape_reg: 0.00020851822046097368, expression_reg: 0.00011393355089239776, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.2175427873816984,
# directional
# ----iter: 260, time: 2023-07-03-16:23:27
# landmark: 1.0740946531295776, shape_reg: 0.00029226497281342745, expression_reg: 0.0001544658443890512, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.205504675694992,
# directional
# ----iter: 270, time: 2023-07-03-16:23:27
# landmark: 1.0629411935806274, shape_reg: 0.00038811611011624336, expression_reg: 0.00019742203585337847, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.194489975759079,
# directional
# ----iter: 280, time: 2023-07-03-16:23:28
# landmark: 1.0525504350662231, shape_reg: 0.0004945337423123419, expression_reg: 0.00024202327767852694, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.1842501362052458,
# directional
# ----iter: 290, time: 2023-07-03-16:23:28
# landmark: 1.0431733131408691, shape_reg: 0.0006099027232266963, expression_reg: 0.00028757553081959486, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.1750339468207853,
# directional
# ----iter: 300, time: 2023-07-03-16:23:28
# landmark: 1.0343159437179565, shape_reg: 0.0007319035357795656, expression_reg: 0.0003334122011438012, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.1663445432868498,
# directional
# ----iter: 310, time: 2023-07-03-16:23:28
# landmark: 1.0263324975967407, shape_reg: 0.0008584416355006397, expression_reg: 0.00037858044379390776, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.158532758542587,
# directional
# ----iter: 320, time: 2023-07-03-16:23:28
# landmark: 1.0191166400909424, shape_reg: 0.0009866980835795403, expression_reg: 0.00042030905024148524, pose_reg: 0.0, photometric_texture: 1.1309632261481781, all_loss: 2.151486893483688,
# directional
# ----iter: 330, time: 2023-07-03-16:23:28
# ...
# directional
# ----iter: 340, time: 2023-07-03-16:49:09
# landmark: 0.9824814796447754, shape_reg: 0.0012001815484836698, expression_reg: 0.0004692833754234016, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.2276323037694663,
# directional
# ----iter: 350, time: 2023-07-03-16:49:09
# landmark: 0.9761713743209839, shape_reg: 0.001331768580712378, expression_reg: 0.0005074174841865897, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.2214918928693503,
# directional
# ----iter: 360, time: 2023-07-03-16:49:09
# landmark: 0.970117449760437, shape_reg: 0.0014669036027044058, expression_reg: 0.0005459365202113986, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.215611656243679,
# directional
# ----iter: 370, time: 2023-07-03-16:49:10
# landmark: 0.9642482995986938, shape_reg: 0.0016058719484135509, expression_reg: 0.0005848592845723033, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.2099203663419456,
# directional
# ----iter: 380, time: 2023-07-03-16:49:10
# landmark: 0.9585807919502258, shape_reg: 0.0017488570883870125, expression_reg: 0.0006242428789846599, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.2044352489064902,
# directional
# ----iter: 390, time: 2023-07-03-16:49:10
# landmark: 0.9530049562454224, shape_reg: 0.0018959197914227843, expression_reg: 0.0006641391664743423, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1990463333677024,
# directional
# ----iter: 400, time: 2023-07-03-16:49:10
# landmark: 0.9475767612457275, shape_reg: 0.0020470423623919487, expression_reg: 0.000704572768881917, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1938097673009604,
# directional
# ----iter: 410, time: 2023-07-03-16:49:10
# landmark: 0.9421824216842651, shape_reg: 0.0022021669428795576, expression_reg: 0.0007455639424733818, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1886114674161643,
# directional
# ----iter: 420, time: 2023-07-03-16:49:10
# landmark: 0.9368696212768555, shape_reg: 0.0023611930664628744, expression_reg: 0.0007871540728956461, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1834992962430686,
# directional
# ----iter: 430, time: 2023-07-03-16:49:10
# landmark: 0.93165522813797, shape_reg: 0.0025239745154976845, expression_reg: 0.0008293878636322916, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1784899430822104,
# directional
# ----iter: 440, time: 2023-07-03-16:49:11
# landmark: 0.9264392852783203, shape_reg: 0.0026903371326625347, expression_reg: 0.0008723419159650803, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.173483272130367,
# directional
# ----iter: 450, time: 2023-07-03-16:49:11
# landmark: 0.9212711453437805, shape_reg: 0.0028601232916116714, expression_reg: 0.0009160732151940465, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1685286956380576,
# directional
# ----iter: 460, time: 2023-07-03-16:49:11
# landmark: 0.9161538481712341, shape_reg: 0.00303315999917686, expression_reg: 0.0009606470121070743, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.163629015023586,
# directional
# ----iter: 470, time: 2023-07-03-16:49:11
# landmark: 0.9109562039375305, shape_reg: 0.0032092903275042772, expression_reg: 0.0010061099892482162, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1586529808591575,
# directional
# ----iter: 480, time: 2023-07-03-16:49:11
# landmark: 0.9058673977851868, shape_reg: 0.003388378769159317, expression_reg: 0.0010525488760322332, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.153789718682644,
# directional
# ----iter: 490, time: 2023-07-03-16:49:11
# landmark: 0.900720477104187, shape_reg: 0.003570284228771925, expression_reg: 0.0010999948717653751, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.148872097070095,
# directional
# ----iter: 500, time: 2023-07-03-16:49:12
# landmark: 0.8956230282783508, shape_reg: 0.003754890291020274, expression_reg: 0.0011485040886327624, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.14400782161462,
# directional
# ----iter: 510, time: 2023-07-03-16:49:12
# landmark: 0.8904717564582825, shape_reg: 0.00394210172817111, expression_reg: 0.001198135199956596, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1390932994435996,
# directional
# ----iter: 520, time: 2023-07-03-16:49:12
# landmark: 0.8852580189704895, shape_reg: 0.004131808411329985, expression_reg: 0.0012489210348576307, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1341200666974753,
# directional
# ----iter: 530, time: 2023-07-03-16:49:12
# landmark: 0.8800548315048218, shape_reg: 0.004323985893279314, expression_reg: 0.0013009087415412068, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1291610794614524,
# directional
# ----iter: 540, time: 2023-07-03-16:49:12
# landmark: 0.8748970031738281, shape_reg: 0.004518521949648857, expression_reg: 0.0013541242806240916, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1242509680341453,
# directional
# ----iter: 550, time: 2023-07-03-16:49:12
# landmark: 0.8696512579917908, shape_reg: 0.004715374205261469, expression_reg: 0.0014086093287914991, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1192566352437705,
# directional
# ----iter: 560, time: 2023-07-03-16:49:13
# landmark: 0.8642566800117493, shape_reg: 0.004916223231703043, expression_reg: 0.0014645967166870832, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.114118893678066,
# directional
# ----iter: 570, time: 2023-07-03-16:49:13
# landmark: 0.8589281439781189, shape_reg: 0.0051237791776657104, expression_reg: 0.0015220616478472948, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.109055359895107,
# directional
# ----iter: 580, time: 2023-07-03-16:49:13
# landmark: 0.8536044955253601, shape_reg: 0.005333695560693741, expression_reg: 0.001580872805789113, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.1040004687856406,
# directional
# ----iter: 590, time: 2023-07-03-16:49:13
# landmark: 0.8483200669288635, shape_reg: 0.005544354673475027, expression_reg: 0.0016412484692409635, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0989870625089377,
# directional
# ----iter: 600, time: 2023-07-03-16:49:13
# landmark: 0.8429378867149353, shape_reg: 0.005756010301411152, expression_reg: 0.0017026973655447364, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0938779907773704,
# directional
# ----iter: 610, time: 2023-07-03-16:49:13
# landmark: 0.8375775814056396, shape_reg: 0.005969255696982145, expression_reg: 0.0017652974929660559, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0887934761594504,
# directional
# ----iter: 620, time: 2023-07-03-16:49:14
# landmark: 0.8322413563728333, shape_reg: 0.006184297613799572, expression_reg: 0.0018294157925993204, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.083736439282772,
# directional
# ----iter: 630, time: 2023-07-03-16:49:14
# landmark: 0.8268531560897827, shape_reg: 0.00640120217576623, expression_reg: 0.0018950313096866012, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.078630705411312,
# directional
# ----iter: 640, time: 2023-07-03-16:49:14
# landmark: 0.8214303255081177, shape_reg: 0.0066201346926391125, expression_reg: 0.001962128095328808, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.073493917519924,
# directional
# ----iter: 650, time: 2023-07-03-16:49:14
# landmark: 0.8160224556922913, shape_reg: 0.006841191090643406, expression_reg: 0.0020307067316025496, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.068375726277706,
# directional
# ----iter: 660, time: 2023-07-03-16:49:14
# landmark: 0.8105391263961792, shape_reg: 0.007064347621053457, expression_reg: 0.0021007703617215157, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.063185592229244,
# directional
# ----iter: 670, time: 2023-07-03-16:49:15
# landmark: 0.8050571084022522, shape_reg: 0.007289659697562456, expression_reg: 0.00217234599404037, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0580004649709434,
# directional
# ----iter: 680, time: 2023-07-03-16:49:15
# landmark: 0.7995819449424744, shape_reg: 0.007517040707170963, expression_reg: 0.0022453521378338337, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0528257089208335,
# directional
# ----iter: 690, time: 2023-07-03-16:49:15
# landmark: 0.7940868139266968, shape_reg: 0.007746502291411161, expression_reg: 0.002319897757843137, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0476345615934104,
# directional
# ----iter: 700, time: 2023-07-03-16:49:15
# landmark: 0.7884708642959595, shape_reg: 0.007978072389960289, expression_reg: 0.002395918359979987, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.042326231534359,
# directional
# ----iter: 710, time: 2023-07-03-16:49:15
# landmark: 0.7828943729400635, shape_reg: 0.008211683481931686, expression_reg: 0.002473455388098955, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0370608764241904,
# directional
# ----iter: 720, time: 2023-07-03-16:49:15
# landmark: 0.7773213386535645, shape_reg: 0.008447355590760708, expression_reg: 0.0025524883531033993, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0318025546621055,
# directional
# ----iter: 730, time: 2023-07-03-16:49:16
# landmark: 0.7717296481132507, shape_reg: 0.008684994652867317, expression_reg: 0.002632965100929141, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.026528974110958,
# directional
# ----iter: 740, time: 2023-07-03-16:49:16
# landmark: 0.766123354434967, shape_reg: 0.00892460998147726, expression_reg: 0.0027149375528097153, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0212442474912375,
# directional
# ----iter: 750, time: 2023-07-03-16:49:16
# landmark: 0.7605217695236206, shape_reg: 0.009166238829493523, expression_reg: 0.002798421075567603, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.015967805917141,
# directional
# ----iter: 760, time: 2023-07-03-16:49:16
# landmark: 0.754848062992096, shape_reg: 0.009409637190401554, expression_reg: 0.0028832831885665655, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0106223421643943,
# directional
# ----iter: 770, time: 2023-07-03-16:49:16
# landmark: 0.7491910457611084, shape_reg: 0.009655028581619263, expression_reg: 0.0029696528799831867, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 2.0052970843862266,
# directional
# ----iter: 780, time: 2023-07-03-16:49:16
# landmark: 0.7434952855110168, shape_reg: 0.009902275167405605, expression_reg: 0.003057444002479315, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9999363618444177,
# directional
# ----iter: 790, time: 2023-07-03-16:49:16
# landmark: 0.7377601265907288, shape_reg: 0.010151213966310024, expression_reg: 0.0031465813517570496, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9945392804692956,
# directional
# ----iter: 800, time: 2023-07-03-16:49:17
# landmark: 0.7319450378417969, shape_reg: 0.010401995852589607, expression_reg: 0.0032372106797993183, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9890656071256372,
# directional
# ----iter: 810, time: 2023-07-03-16:49:17
# landmark: 0.7262118458747864, shape_reg: 0.010654392652213573, expression_reg: 0.003329106140881777, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9836766915868493,
# directional
# ----iter: 820, time: 2023-07-03-16:49:17
# landmark: 0.7204370498657227, shape_reg: 0.010908467695116997, expression_reg: 0.0034223853144794703, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9782492714475366,
# directional
# ----iter: 830, time: 2023-07-03-16:49:17
# landmark: 0.7146405577659607, shape_reg: 0.011164229363203049, expression_reg: 0.0035170051269233227, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9728031950544092,
# directional
# ----iter: 840, time: 2023-07-03-16:49:17
# landmark: 0.708850085735321, shape_reg: 0.011421357281506062, expression_reg: 0.0036128065548837185, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9673656421254846,
# directional
# ----iter: 850, time: 2023-07-03-16:49:17
# landmark: 0.7030095458030701, shape_reg: 0.01168008055537939, expression_reg: 0.0037099753972142935, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9618809419225427,
# directional
# ----iter: 860, time: 2023-07-03-16:49:18
# landmark: 0.6970931887626648, shape_reg: 0.011940308846533298, expression_reg: 0.0038083274848759174, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9563231664251062,
# directional
# ----iter: 870, time: 2023-07-03-16:49:18
# landmark: 0.6912022233009338, shape_reg: 0.012202061712741852, expression_reg: 0.003907852806150913, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9507935243200036,
# directional
# ----iter: 880, time: 2023-07-03-16:49:18
# landmark: 0.685369610786438, shape_reg: 0.012464853934943676, expression_reg: 0.004008447751402855, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9453243213247033,
# directional
# ----iter: 890, time: 2023-07-03-16:49:18
# landmark: 0.6794490814208984, shape_reg: 0.012728582136332989, expression_reg: 0.004110072739422321, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9397691088269922,
# directional
# ----iter: 900, time: 2023-07-03-16:49:18
# landmark: 0.6735507845878601, shape_reg: 0.012993855401873589, expression_reg: 0.004212945234030485, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9342389302800866,
# directional
# ----iter: 910, time: 2023-07-03-16:49:18
# landmark: 0.6677749156951904, shape_reg: 0.01325992215424776, expression_reg: 0.004316619131714106, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9288328486036035,
# directional
# ----iter: 920, time: 2023-07-03-16:49:19
# landmark: 0.6617587208747864, shape_reg: 0.013529321178793907, expression_reg: 0.004421223886311054, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9231906133245202,
# directional
# ----iter: 930, time: 2023-07-03-16:49:19
# landmark: 0.6557338833808899, shape_reg: 0.013806252740323544, expression_reg: 0.004527056589722633, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9175484972547265,
# directional
# ----iter: 940, time: 2023-07-03-16:49:19
# landmark: 0.6497576236724854, shape_reg: 0.014081745408475399, expression_reg: 0.004634900484234095, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9119556146215173,
# directional
# ----iter: 950, time: 2023-07-03-16:49:19
# landmark: 0.6438682675361633, shape_reg: 0.01435393188148737, expression_reg: 0.00474260188639164, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9064461784909936,
# directional
# ----iter: 960, time: 2023-07-03-16:49:19
# landmark: 0.6378443241119385, shape_reg: 0.014626296237111092, expression_reg: 0.004850021563470364, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.9008020358632776,
# directional
# ----iter: 970, time: 2023-07-03-16:49:19
# landmark: 0.631862998008728, shape_reg: 0.014897607266902924, expression_reg: 0.0049588498659431934, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.8952008085797998,
# directional
# ----iter: 980, time: 2023-07-03-16:49:20
# landmark: 0.6258434653282166, shape_reg: 0.015168847516179085, expression_reg: 0.005067816935479641, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.8895614939283105,
# directional
# ----iter: 990, time: 2023-07-03-16:49:20
# landmark: 0.6199727058410645, shape_reg: 0.015441020019352436, expression_reg: 0.005177002400159836, pose_reg: 0.0, photometric_texture: 1.2434813576291772, all_loss: 1.8840720849584314,
# directional
